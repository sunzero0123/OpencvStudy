# %% [markdown]
# # **Opencv 기본 사용법**

# %% [markdown]
# CoLab에서 파일 업로드

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-72938903-7ed8-4207-b32e-aa411ad9ffb2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72938903-7ed8-4207-b32e-aa411ad9ffb2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving girl.jpg to girl.jpg

# %% [markdown]
# Opencv의 기본적인 함수
#
#
# *   cv2.imread(file_name,flag) : 이미지를 읽어 Numpy객체로 만드는 함수
# *   cv2.imshow(title,image) : 특정한 이미지를 화면에 출력하는 함수
# * cv2.cvtColor(image,flag) : 이미지 색상 형태를 변경하는 함수

# %% [markdown]
# CoLab에서의 이미지 출력
#
#
# *   CoLab은 jupyter Notebook을 기반으로 하여 동작하므로 Matplotlib를 이용하여 이미지를 출력한다.
# *   Opencv는 BGR을 기준으로 하여, Matplotlib는 RGB를 기준으로 한다.

# %%
import cv2
import matplotlib.pyplot as plt

img_basic = cv2.imread('girl.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()

img_basic = cv2.cvtColor(img_basic, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_GRAY2RGB))
plt.show()
